# %%
import bmll2 as b2
from bmll2 import reference, Security, NormalisedSecurity, SparkHelper, get_market_data, get_market_data_range, VenueMarketError, get_market_tables, save_spark_dataframe, load_spark_dataframe

import random
import math
import pandas as pd
import polars as pl
import numpy as np
from pandas import StringDtype
import gc

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import LogFormatterSciNotation
from scipy.stats import linregress
from scipy.optimize import curve_fit
from scipy.stats import t

# %%
N                   = 20
trader_distribution = 'power'
alpha               = 2
group               = 'day'
identifier          = f'{trader_distribution}_{N}_{group}_pl'
exchange            = 'XJSE'
ticker              = 'GRT'

# %%
b2.get_file(f'data/concave_profile/{exchange}/{identifier}/{ticker}_{exchange}_concave_profile_data_{identifier}.parquet')
profile_data = pl.read_parquet(f'{ticker}_{exchange}_concave_profile_data_{identifier}.parquet')
profile_data.head()
# Out:
# shape: (5, 15)
# ┌──────┬────────┬────────────┬─────────────────┬───┬────────┬──────────┬───────────┬───────────┐
# │ MIC  ┆ Ticker ┆ Date       ┆ DateTime        ┆ … ┆ volume ┆ phi      ┆ scaled    ┆ metaorder │
# │ ---  ┆ ---    ┆ ---        ┆ ---             ┆   ┆ traded ┆ ---      ┆ impact    ┆ impact    │
# │ str  ┆ str    ┆ date       ┆ datetime[μs]    ┆   ┆ ---    ┆ f64      ┆ ---       ┆ ---       │
# │      ┆        ┆            ┆                 ┆   ┆ f64    ┆          ┆ f64       ┆ f64       │
# ╞══════╪════════╪════════════╪═════════════════╪═══╪════════╪══════════╪═══════════╪═══════════╡
# │ XJSE ┆ GRT    ┆ 2023-01-03 ┆ 2023-01-03      ┆ … ┆ 4051.0 ┆ 0.108121 ┆ -0.0      ┆ -0.002406 │
# │      ┆        ┆            ┆ 10:24:37.118383 ┆   ┆        ┆          ┆           ┆           │
# │ XJSE ┆ GRT    ┆ 2023-01-03 ┆ 2023-01-03      ┆ … ┆ 4051.0 ┆ 0.117749 ┆ 0.470369  ┆ -0.002406 │
# ...

# %%
bins = np.linspace(0, 1, 51)

df = profile_data.with_columns(pl.col('phi').cut(bins).alias('bin'))
df = df.group_by('bin').agg(pl.col('scaled impact').mean().alias('scaled impact (binned)')).sort('bin')

scaled_impact_binned = df['scaled impact (binned)']
prepend_value        = pl.Series(name = 'scaled impact (binned)', values = [0.0], dtype = scaled_impact_binned.dtype)
scaled_impact_binned = pl.concat([prepend_value, scaled_impact_binned], how = 'vertical')
bin_mids = (bins[:-1] + bins[1:]) / 2
bin_mids = np.insert(bin_mids, 0, 0)

# %%
def execution_profile_model(phi, exponent, Y):
    return  Y * (phi ** exponent)

phi    = np.array(bin_mids)
impact = np.array(scaled_impact_binned)

mask       = phi > 0 
phi_fit    = phi[mask]
impact_fit = impact[mask]

params, covariance = curve_fit(execution_profile_model, phi_fit, impact_fit, p0 = [0.5, 0.0002])

exponent_est = params[0]
Y_est        = params[1]
print('Estimated exponent:', exponent_est)
print('Estimated peak impact', Y_est)

fitted_curve = execution_profile_model(bin_mids, exponent_est, Y_est)

n   = len(phi_fit)
p   = len(params)          # number of parameters (2 here)
dof = n - p                # degrees of freedom

alpha = 0.05               # 95% CI
tval  = t.ppf(1 - alpha / 2, dof)
se    = np.sqrt(np.diag(covariance))
interval_half_widths = tval * se[0], tval * se[1]
print('Interval half widths:', interval_half_widths)

Y_ci        = Y_est - tval * se[1], Y_est + tval * se[1]
exponent_ci = exponent_est - tval * se[0], exponent_est + tval * se[0]
print('Scaling Y 95% CI:', Y_ci)
print('Exponent 95% CI:', exponent_ci)
# Out:
# Estimated exponent: 0.791325261057901
# Estimated peak impact 1.2249065153472318
# Interval half widths: (0.047749973941034266, 0.03203179267978512)
# Scaling Y 95% CI: (1.1928747226674468, 1.256938308027017)
# Exponent 95% CI: (0.7435752871168667, 0.8390752349989353)

# %%
b2.create_folder('figures_2', ensure_exists = True)
b2.create_folder('figures_2/concave_profile', ensure_exists = True)
b2.create_folder(f'figures_2/concave_profile/{exchange}', ensure_exists = True) 
b2.create_folder(f'figures_2/concave_profile/{exchange}/{identifier}', ensure_exists = True)

# %%
if ticker == 'GRT':
    col = 'olive'
if ticker == 'GFI':
    col = 'purple'

# %%
fig, ax = plt.subplots(figsize = (6, 6))

ax.scatter(bin_mids, scaled_impact_binned, color = col, marker = 'o', label = f'{ticker} dynamic impact')
ax.set_xlabel(r'Rescaled volume time $\phi = \sum q_i/Q$', fontsize = 14)
ax.set_ylabel(r'Dynamic impact $\frac{I(\phi Q)}{\sigma_{D} \sqrt{Q/V_{D}}}$', fontsize = 14)
ax.plot(bin_mids, fitted_curve, color = 'red', linestyle = '--', label = rf'Fitted curve: $Y \times\phi^{{{exponent_est:.2f}}}$')
ax.set_yscale('linear')
ax.legend()

ax.set_box_aspect(1)
plt.tight_layout()

plt.savefig(f'{ticker}_{exchange}_concave_profile_{identifier}.pdf')
b2.put_file(f'{ticker}_{exchange}_concave_profile_{identifier}.pdf', f'figures_2/concave_profile/{exchange}/{identifier}')
b2.get_file(f'figures_2/concave_profile/{exchange}/{identifier}/{ticker}_{exchange}_concave_profile_{identifier}.pdf')

plt.show()

# %%
execution_concavity_table = pd.DataFrame({'': ['GFI', 'GRT'], 'scaling factor': [Y_est_GFI, Y_est_GRT],
                                          'exponent': [exponent_est_GFI, exponent_est_GRT]})
print(execution_concavity_table.to_latex(index = False, caption = 'Fitted values for metaorder execution profiles of GFI and GRT',
                                         label = 'tab:execution profile values'))

# %%
profile_data = profile_data.with_columns((pl.col('metaorder impact') * pl.col('phi').sqrt() * pl.col('20 AD volume').sqrt() / (pl.col('20 AD volatility') * pl.col('volume traded').sqrt())).alias('theoretic impact'))
# Out:
# shape: (5, 16)
# ┌──────┬────────┬────────────┬─────────────┬───┬──────────┬─────────────┬─────────────┬────────────┐
# │ MIC  ┆ Ticker ┆ Date       ┆ DateTime    ┆ … ┆ phi      ┆ scaled      ┆ metaorder   ┆ theoretic  │
# │ ---  ┆ ---    ┆ ---        ┆ ---         ┆   ┆ ---      ┆ impact      ┆ impact      ┆ impact     │
# │ str  ┆ str    ┆ date       ┆ datetime[μs ┆   ┆ f64      ┆ ---         ┆ ---         ┆ ---        │
# │      ┆        ┆            ┆ ]           ┆   ┆          ┆ f64         ┆ f64         ┆ f64        │
# ╞══════╪════════╪════════════╪═════════════╪═══╪══════════╪═════════════╪═════════════╪════════════╡
# │ XJSE ┆ GRT    ┆ 2023-01-03 ┆ 2023-01-03  ┆ … ┆ 0.108121 ┆ -0.0        ┆ -0.002406   ┆ -1.081174  │
# │      ┆        ┆            ┆ 10:24:37.11 ┆   ┆          ┆             ┆             ┆            │
# │      ┆        ┆            ┆ 8383        ┆   ┆          ┆             ┆             ┆            │
# ...

# %%
profile_data.filter(pl.col('number child orders') > 9)[10:25, : ]
# Out:
# shape: (15, 16)
# ┌──────┬────────┬────────────┬─────────────┬───┬──────────┬─────────────┬─────────────┬────────────┐
# │ MIC  ┆ Ticker ┆ Date       ┆ DateTime    ┆ … ┆ phi      ┆ scaled      ┆ metaorder   ┆ theoretic  │
# │ ---  ┆ ---    ┆ ---        ┆ ---         ┆   ┆ ---      ┆ impact      ┆ impact      ┆ impact     │
# │ str  ┆ str    ┆ date       ┆ datetime[μs ┆   ┆ f64      ┆ ---         ┆ ---         ┆ ---        │
# │      ┆        ┆            ┆ ]           ┆   ┆          ┆ f64         ┆ f64         ┆ f64        │
# ╞══════╪════════╪════════════╪═════════════╪═══╪══════════╪═════════════╪═════════════╪════════════╡
# │ XJSE ┆ GRT    ┆ 2023-01-03 ┆ 2023-01-03  ┆ … ┆ 0.123015 ┆ -0.0        ┆ 0.001709    ┆ 0.225642   │
# │      ┆        ┆            ┆ 13:08:29.08 ┆   ┆          ┆             ┆             ┆            │
# │      ┆        ┆            ┆ 8568        ┆   ┆          ┆             ┆             ┆            │
# ...

# %%
test = profile_data.filter((pl.col('trader id') == 19) & (pl.col('metaorder id') == 73) & (pl.col('Date') == pl.datetime(2025, 12, 30)))
test
# Out:
# shape: (10, 16)
# ┌──────┬────────┬────────────┬─────────────┬───┬──────────┬─────────────┬─────────────┬────────────┐
# │ MIC  ┆ Ticker ┆ Date       ┆ DateTime    ┆ … ┆ phi      ┆ scaled      ┆ metaorder   ┆ theoretic  │
# │ ---  ┆ ---    ┆ ---        ┆ ---         ┆   ┆ ---      ┆ impact      ┆ impact      ┆ impact     │
# │ str  ┆ str    ┆ date       ┆ datetime[μs ┆   ┆ f64      ┆ ---         ┆ ---         ┆ ---        │
# │      ┆        ┆            ┆ ]           ┆   ┆          ┆ f64         ┆ f64         ┆ f64        │
# ╞══════╪════════╪════════════╪═════════════╪═══╪══════════╪═════════════╪═════════════╪════════════╡
# │ XJSE ┆ GRT    ┆ 2025-12-30 ┆ 2025-12-30  ┆ … ┆ 0.2123   ┆ -0.0        ┆ 0.001146    ┆ 1.10452    │
# │      ┆        ┆            ┆ 16:34:58.53 ┆   ┆          ┆             ┆             ┆            │
# │      ┆        ┆            ┆ 1166        ┆   ┆          ┆             ┆             ┆            │
# ...

# %%
fig, ax = plt.subplots(figsize = (6, 6))

ax.plot(test['phi'], test['scaled impact'], color = 'blue', marker = 'o', label = f'{ticker} dynamic impact')
ax.set_xlabel(r'Rescaled volume time $\phi = \sum q_i/Q$', fontsize = 14)
ax.set_ylabel(r'Dynamic impact $\frac{I(\phi Q)}{\sigma_{D} \sqrt{Q/V_{D}}}$', fontsize = 14)
ax.plot(test['phi'], test['theoretic impact'], color = 'red', linestyle = '--', label = rf'Fitted curve: $Y \times\phi^{{0.5}}$')
ax.set_yscale('linear')
ax.legend()
